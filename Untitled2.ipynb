# %%
# %matplotlib notebook

import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as pf
import time

# %%
field = 'Goodss/'
way  = 'tweak_cosmos_v4/'
name = 'eazy_v1.1_sed'
name_cat = 'goodss_3dhst.v4.1.cat'

# Load all model spectra and main catalog
list =  glob.glob(way + 'eazy*.dat')
main_cat = np.genfromtxt(name_cat, skip_header=2)

# %%
# Работа с архивом данных, остаются только те, номера которых указаны в filtr
def find(cat, name, filtr):
    with open(cat, 'r') as f:
        with open(name, 'w') as y:
            lines = f.readlines()

            for i, line in enumerate(lines):
                if i <= 1:
                    y.write(line)
                for j in range(len(filtr)):
                    if i == filtr[j] + 2:
                        y.write(line)
    print('END')

# %%
# The function of shifting the wavelength and modification amplitude of the flux
#def func_1(z, x, y):
#    l_mod  = (1+z) * x
#    mod_flux = y
#    return l_mod, mod_flux

# %%
from scipy import interpolate
global cof

table = np.loadtxt('table_transmition_ISM.dat')
lam_rest   = table[1:,0]
z          = table[0, 1:]
trans_coef = table[1:, 1:]
cof = interpolate.interp2d(z, lam_rest, trans_coef)

# %%
# A function that takes into account the transmission curves and response function from each filter
def chi2(z, lcii, x, y, fil, filty, fil_inf, fil_name, hyt, toplot=False):
   
    moh = np.zeros(len(x))

    # Add absorption for object
    ging = []
    for i in range (len(x)): 
        moh[i] =  cof(z, x[i]) * y[i] 
        ging.append(cof(z, x[i]))
    
    
    # Find the template corresponding to our z
    #l_obs2, sp_ext = func_1(z, x, moh)
    l_obs2 = (1+z)*x
    sp_ext = moh
    
    
    # Sorting
    l_obs2 = np.array(l_obs2)
    lcii = np.array(lcii)
        
    #sp_ext = sp_ext[np.argsort(l_obs2)]
    #l_obs2 = l_obs2[np.argsort(l_obs2)]
    mean_lambda = []
    fit = []    
    # Add response function for all filters
    for i in range(len(fil)):
        num = 0
        spectr = sp_ext.copy()
        
        res, n = get_filter_by_id(fil[i], filty, fil_inf, fil_name)
        
        # Load lambda and flux from response function
        x_res  = res[:, 1]
        y_res  = res[:, 2]
        
        x_filt = np.array(x_res)
        y_filt = np.array(y_res)
        
        lim1   = np.min(x_res)
        lim2   = np.max(x_res)
        
        # Load template lambda
        xx_tem = l_obs2[np.where((l_obs2 >= lim1) & (l_obs2 <= lim2))[0]]
        
        filt_int  = np.interp(xx_tem, x_filt, y_filt) 
        #print(filt_int)
        
        num = (1+z) * np.trapz(spectr[np.where((l_obs2 >= lim1) & (l_obs2 <= lim2))[0]]*filt_int, xx_tem)/(np.trapz(filt_int, xx_tem))  
        mean_lambda.append((lim1+lim2)/2)
        fit.append(num)
        
        #print("filter", n)
     

    return fit, mean_lambda

# %%
def hst_flux(id):
    # The column numbers of the flux in the main catalog
    num_fc  = np.array(([18, 30, 39, 48, 75, 78, 81, 84, 57, 66, \
                     72, 21, 24, 36, 42, 15, 12, 87, 89, 91, \
                     93, 95, 97, 99, 101, 103, 105, 107, 109, 111, \
                     113, 54, 63, 9, 60, 69, 27, 45, 51, 33]))


    # The column numbers of the errors in the main catalog
    num_efc = np.array(([19, 31, 40, 49, 76, 79, 82, 85, 58, 67, \
                     73, 22, 25, 37, 43, 16, 13, 88, 90, 92,  \
                     94, 96, 98, 100, 102, 104, 106, 108, 110, 112, \
                     114, 55, 64, 10, 61, 70, 28, 46, 52, 34]))

    # Name of filters
    fil_cat = ['F435', 'F606W', 'F775W', 'F850LP', 'IRAC1', 'IRAC2', 'IRAC3', 'IRAC4', 'J', 'H', \
               'Ks', 'B', 'V', 'Rc',  'I', 'U', 'U38', 'IA427', 'IA445', 'IA505', 'IA527', 'IA550', \
               'IA574', 'IA598', 'IA624', 'IA651', 'IA679', 'IA738', 'IA767', 'IA797', 'IA856', 'F125W', \
               'F140W', 'F160W', 'tenisJ',  'tenisK', 'F606cand',  'F814Wcand', 'F850LPcand', 'R' ]


    # Central wavelengths of filters
    lambd = np.array(([0.4318, 0.5919, 0.7693, 0.9036, 3.5569, 4.5020, 5.7450, 7.9158, 1.2356, 1.6496, \
                       2.1667, 0.4563, 0.5396, 0.6517, 0.7838, 0.3750, 0.3637, 0.4260, 0.4443, 0.5061, \
                       0.5259, 0.5495, 0.5763, 0.6007, 0.6231, 0.6498, 0.6782, 0.7359, 0.7680, 0.7966,\
                       0.8565, 1.2471, 1.3924, 1.5396, 1.2530, 2.1574, 0.5921, 0.8057, 0.9033, 0.6443
                      ]))
    
    # Spectrum from the catalog HST
    flux_c = []
    erflu_c = []
    filt = []

    for j in range(len(num_fc)):
        for i in range(len(main_cat[0, :])):
            if (i == num_fc[j]) & (main_cat[id - 1, i] > 0):
                flux_c.append(main_cat[id - 1, i])
                erflu_c.append(main_cat[id - 1, int(num_efc[j])])
                filt.append(j)
                
    # Translate the wavelength into angstroms
    lci = lambd[filt] * 10 ** 4

    # Reproduce to a good type
    flux_c = np.array(flux_c)
    erflu_c = np.array(erflu_c)

    # Translate the flow into nano Jansky
    flux_c = [flux_c[i] * 10 ** (2.56) for i in range(len(flux_c))]
    erflu_c = [erflu_c[i] * 10**(2.56) for i in range(len(erflu_c))]

    # Reproduce to a good type again
    flux_c = np.array(flux_c)
    erflu_c = np.array(erflu_c)
    
    
    return lci, flux_c, erflu_c, filt

# %%
def filt_f():
    #fname = field + 'Eazy/' + 'goodss_3dhst.v4.1.translate'
    fname = 'goodss_3dhst.v4.1.translate'
    filt_list = np.genfromtxt(fname, dtype=None)


    fil = []
    num_fil = []
    for i, j in zip(filt_list[:, 1], np.linspace(0, 87, 88)):
        if j % 2 == 0:
            num_fil.append(np.array(i[1:]).astype(int))
            # print(np.array(i[1:]).astype(int))


    for i, j in zip(filt_list[:, 0], np.linspace(0, 87, 88)):
        if j % 2 == 0:
            fil.append(np.array(i[2:]).astype(str))


    num_fil = np.array(num_fil)
    fil = np.array(fil)

    # Filters and their numbers
    fil = fil[np.argsort(num_fil)]
    num_fil = num_fil[np.argsort(num_fil)]

    # Delete filters that are not in the article
    hi = [19, 20, 29, 33]
    num_fil = np.delete(num_fil, hi)
    fil = np.delete(fil, hi)
    #-------------------------
    
    filters_info = []
    for line in open( 'FILTER.RES.latest.info', 'r'):
        filters_info.append(np.array(line.split()))
    filters_info = np.array(filters_info)
    #--------------------------
    
    temp_filters = open('FILTER.RES.latest', 'r')
    filters = []
    filters_names = []
    first = True

    l = 0
    for line in temp_filters:

        if line[0] == ' ':

            if not first:
                filters.append(np.array(temp))
                l += 1

            first = False
            filters_names.append(line.split())
            temp = []

        else:
            temp.append(np.array(line.split()).astype('float'))
    
    # filters - include response function for each filter
    # filters_name - include all filters name

    filters = np.array(filters)
    filters_names = np.array(filters_names)
    
    return num_fil, filters, filters_info, filters_names
    
    
# It return name and response function for each filter by id in num_fil
def get_filter_by_id(idi,filtt, filters_info, filters_names):
    temp = np.array([a[0] for a in filters_info]).astype(int)
    name = filters_info[np.where(temp == idi)[0][0]][1]
    names = np.array([a[1] for a in filters_names])
    lam =  np.array([a[4] for a in filters_info[np.where(name == names)[0]]])
    ress = filtt[np.where(name == names)[0][0]]
   
    return ress, name

# %%
def get_z(id):
    
    
    lci, flux_c, erflu_c, filt = hst_flux(id)
    num_fill, filters, filters_info, filters_names  = filt_f()
    
    # Take for response function only those filters which have flux in data
    num_fill = num_fill[filt]
    
    z_list = np.arange(0, 8, 0.5)
    L_best = np.zeros(len(z_list))
    templates_n = np.zeros(len(z_list))
    
    for i in range(len(z_list)):
        L = np.zeros(6)
        for k in range(6):
            # Template wavelengths and fluxes
            x = np.genfromtxt(list[k])[:, 0]
            y = np.genfromtxt(list[k])[:, 1]
            
            fitz, mean_lambda = chi2(z_list[i], lci, x, y, num_fill, filters, filters_info, filters_names, flux_c)
            fitz = np.array(fitz)
            
            a = np.sum(fitz**2 / erflu_c**2)
            b = -2*np.sum(flux_c*fitz/ erflu_c**2)    
            n = -b/(2*a)

            L[k] = np.sum((flux_c - n*fitz)** 2 / (np.array(erflu_c) ** 2) )
   
        templates_n[i] = np.argmin(L)   
        L_best[i] = L[int(templates_n[i])]
     
    # the best z
    redsh = z_list[np.argmin(L_best)]
    
    
    # all the lines below are only for data visualization and examination
    tt = int(templates_n[np.argmin(L_best)])
    x = np.genfromtxt(list[tt])[:, 0]
    y = np.genfromtxt(list[tt])[:, 1] 
    
    
    fitz, mean_lambda  = chi2(redsh, lci, x, y, num_fill, filters, filters_info, filters_names, flux_c)
    fitz = np.array(fitz)
    
    
    a = np.sum(fitz**2 / erflu_c**2)
    b = -2*np.sum(flux_c*fitz/ erflu_c**2)    
    n = -b/(2*a)
    
    
    mean_lambda = np.array(mean_lambda)
    
    
    return redsh,n,fitz,mean_lambda, np.amin(L_best)
    #return z_list, K, redsh

# %%
f = 0
crit = []    # ID objects which you want 
z_spec = []
for i in range (len(main_cat)):
    if    2.47 < main_cat[i,120] < 2.53 or  1.47 < main_cat[i,120] < 1.53 \
    or 3.47 < main_cat[i,120] < 3.53:
        f+=1
        z_spec.append(main_cat[i,120])
        crit.append(int(main_cat[i,0]))
    
print(f)


print(np.round(z_spec,1))
# Out:
# 16
# [ 1.5  2.5  2.5  3.5  3.5  2.5  3.5  3.5  3.5  3.5  3.5  3.5  1.5  2.5  1.5
#   1.5]

# %%
# Find z for all object which was choosen previously  
z_my = []
h=0
for i in crit:
    red = get_z(i)
    z_my.append(red)
    h+=1
    if h % 10 == 0:
        print("Next step = " + str(h))
# Out:
# Next step = 10

# %%
z_my
# Out:
# [(1.0,
#   10912.04735603997,
#   array([ 0.11370449,  0.37139095,  0.93212049,  1.60507767,  1.00383178,
#           0.49449445,  0.22259519,  0.07977874,  2.14423815,  1.86109421,
#           0.12331582,  0.20898018,  0.51364251,  1.42679295,  0.09888394,
#           0.09946689,  0.11714241,  0.12072464,  0.14100305,  0.20432238,
#           0.21099438,  0.303328  ,  0.38777874,  0.44649639,  0.53180737,
#           0.57105904,  0.76107219,  0.81880392,  1.06304279,  1.29895046,
#           2.14313297,  2.15046422,  2.15997486,  2.14726629,  1.86803388,
#           1.12729818,  1.60378179,  0.50326255]),
#   array([  4225. ,   5890. ,   7597.5,   9375. ,  35247.5,  44425. ,
#           57560. ,  80610. ,  12145. ,  21585. ,   5355. ,   5395. ,
#            6935. ,   9122.5,   3595. ,   3635. ,   4255. ,   4445. ,
#            5047.5,   5250. ,   5492.5,   5747.5,   5985. ,   6220. ,
#            6500. ,   6810. ,   7350. ,   7652.5,   7977.5,   8572.5,
#           12460. ,  13875. ,  13770. ,  12490. ,  21460. ,   8220. ,
#            9370. ,   7600. ])),
#  (2.0,
#   411.31663896006575,
#   array([ 3.30697383,  2.80000346,  2.76826999,  0.97459094,  0.60404731,
#           0.32705356,  0.11034443,  4.00600598,  2.14875504,  3.41685338,
#           3.65747871,  3.0523773 ,  2.79676094,  2.46827916,  2.3663759 ,
#           3.3023614 ,  3.41728711,  3.63998446,  3.73178038,  3.70158459,
#           3.52277744,  3.36570256,  3.19979532,  2.99855932,  2.83784232,
#           2.83770356,  2.74825303,  2.88089613,  2.78056318,  3.97648849,
#           3.87893588,  3.49869835,  4.14223299,  2.1716007 ,  2.79906969,
#           2.76846837,  3.06604845]),
#   array([  5890. ,   7597.5,   9375. ,  35247.5,  44425. ,  57560. ,
#           80610. ,  12145. ,  21585. ,   5355. ,   5395. ,   6935. ,
#            9122.5,   3595. ,   3635. ,   4255. ,   4445. ,   5047.5,
#            5250. ,   5492.5,   5747.5,   5985. ,   6220. ,   6500. ,
#            6810. ,   7350. ,   7652.5,   7977.5,   8572.5,  12460. ,
#           13875. ,  13770. ,  12490. ,  21460. ,   8220. ,   9370. ,   7600. ])),
#  (2.5,
#   1.3901580687410127e-27,
#   array([  1.60241890e+29,   3.03669420e+29,   3.68113387e+29,
#            4.35447216e+29,   1.73787468e+30,   1.61033924e+30,
#            1.32666209e+30,   6.45762338e+29,   7.99617189e+29,
#            1.47551081e+30,   1.74090817e+30,   1.98851771e+29,
#            2.62554949e+29,   3.40181362e+29,   4.11610162e+29,
#            4.25056376e+28,   3.60039452e+28,   2.38679210e+29,
#            1.61896597e+29,   2.44142213e+29,   2.50222453e+29,
#            2.61606461e+29,   3.05063264e+29,   3.25912222e+29,
#            3.41930201e+29,   3.43218015e+29,   3.44762690e+29,
#            3.60123835e+29,   3.61592166e+29,   3.69570134e+29,
#            4.11116579e+29,   8.03495766e+29,   1.09368861e+30,
#            1.24231747e+30,   8.47934242e+29,   1.87147787e+30,
#            3.03793176e+29,   3.86704698e+29,   4.35268921e+29,
#            3.39772842e+29]),
#   array([  4225. ,   5890. ,   7597.5,   9375. ,  35247.5,  44425. ,
#           57560. ,
#            4.12240396e+29,   1.05217346e+30,   1.19845027e+30,
#            1.27954799e+30,   1.05296898e+30,   1.35814352e+30,
#            3.87326149e+29,   4.27335094e+29,   3.10995701e+29]),
#   array([  4225. ,   5890. ,   7597.5,   9375. ,  35247.5,  44425. ,
#           57560. ,  80610. ,  12145. ,  16425. ,  21585. ,   5355. ,
#            5395. ,   6935. ,   9122.5,   3595. ,   3635. ,   4255. ,
#            4445. ,   5047.5,   5250. ,   5492.5,   5747.5,   5985. ,
#            6220. ,   6500. ,   6810. ,   7350. ,   7652.5,   7977.5,
#            8572.5,  12460. ,  13875. ,  13770. ,  12490. ,  21460. ,
#            8220. ,   9370. ,   7600. ]))]

# %%
z_my_flat = []
error_my_flat = []
for i in range(len(crit)):
    z_my_flat.append(z_my[i][0])
    #error_my_flat.append(np.log10(z_my[i][4]))
    
fig = plt.figure(48, figsize=(12, 5) )
ax = fig.add_subplot(1,2,1)
a = ax.scatter(z_spec, np.array(z_my_flat), cmap='jet',alpha=0.8,c=np.arange(len(crit)),s=150)
ax.set_xlabel("z_spec", fontsize=17)
ax.set_ylabel("z_my", fontsize=17)
 
ax.set_xlim(0.5, 7)
ax.set_ylim(0.5, 7)
plt.plot([0.5, 1, 2, 3, 4, 5, 6, 7, 8], [0.5, 1, 2, 3, 4, 5, 6, 7, 8], color = "blue", lw = 1)
plt.colorbar(a)

error = np.array(z_my_flat)-np.array(z_spec)
ax2 = fig.add_subplot(1,2,2)
ax2.set_xlabel('Error $\\Delta z$')
ax2.set_ylabel('N of objects')
ax2.hist(error,bins=np.linspace(-5,5,10))
# Out:
# <img src="data:image/png;base64,...">
# (array([  0.,   3.,   0.,   0.,  12.,   1.,   0.,   0.,   0.]),
#  array([-5.        , -3.88888889, -2.77777778, -1.66666667, -0.55555556,
#          0.55555556,  1.66666667,  2.77777778,  3.88888889,  5.        ]),
#  <a list of 9 Patch objects>)

# %%
idx = 12
print("Object = " + str(crit[idx]) )
plt.close()
lci, flux_c, erflu_c, filt = hst_flux(crit[idx])
fig = plt.figure(10,figsize=(12, 5))
ax=fig.add_subplot(1,2,1)
x = np.genfromtxt(list[1])[:, 0]
y = np.genfromtxt(list[1])[:, 1]

ax.set_title('z_spec = ' + str(np.round(z_spec[idx],1)) + ', z_my =  ' + str(np.round(z_my[idx][0],1)))   
ax.plot(lci ,flux_c, '^')
ax.plot(np.array(z_my[idx][3]),np.array(z_my[idx][2])*z_my[idx][1],'o')
ax.set_xscale('log')
ax.set_xlim([1000, 100000])


ax2=fig.add_subplot(1,2,2)
ax2.scatter(z_spec[idx], np.array(z_my_flat)[idx], cmap='jet',alpha=0.8,s=150)
ax2.set_xlabel("z_spec", fontsize=17)
ax2.set_ylabel("z_my", fontsize=17)
#plt.text(max(z_my)-1.2, min(z_my),  'N_obj = ' + str(len(z_spec)),
#                      style='italic', bbox={'facecolor':'red', 'alpha':1.2, 'pad':2})  
ax2.set_xlim(0.5, 7)
ax2.set_ylim(0.5, 7)
ax2.plot([0.5, 1, 2, 3, 4, 5, 6, 7, 8], [0.5, 1, 2, 3, 4, 5, 6, 7, 8], color = "blue", lw = 1)
# Out:
# Object = 32187
# <img src="data:image/png;base64,...">

# %%
idx = 11
print("Object = " + str(crit[idx]) )
plt.close()
lci, flux_c, erflu_c, filt = hst_flux(crit[idx])
fig = plt.figure(10,figsize=(12, 5))
ax=fig.add_subplot(1,2,1)
x = np.genfromtxt(list[1])[:, 0]
y = np.genfromtxt(list[1])[:, 1]

ax.set_title('z_spec = ' + str(np.round(z_spec[idx],1)) + ', z_my =  ' + str(np.round(z_my[idx][0],1)))   
ax.plot(lci ,flux_c, '^')
ax.plot(np.array(z_my[idx][3]),np.array(z_my[idx][2])*z_my[idx][1],'o')
ax.set_xscale('log')
ax.set_xlim([1000, 100000])


ax2=fig.add_subplot(1,2,2)
ax2.scatter(z_spec[idx], np.array(z_my_flat)[idx], cmap='jet',alpha=0.8,s=150)
ax2.set_xlabel("z_spec", fontsize=17)
ax2.set_ylabel("z_my", fontsize=17)
#plt.text(max(z_my)-1.2, min(z_my),  'N_obj = ' + str(len(z_spec)),
#                      style='italic', bbox={'facecolor':'red', 'alpha':1.2, 'pad':2})  
ax2.set_xlim(0.5, 7)
ax2.set_ylim(0.5, 7)
ax2.plot([0.5, 1, 2, 3, 4, 5, 6, 7, 8], [0.5, 1, 2, 3, 4, 5, 6, 7, 8], color = "blue", lw = 1)
# Out:
# Object = 28864
# <img src="data:image/png;base64,...">

# %%
def get_z(id):
    
    
    lci, flux_c, erflu_c, filt = hst_flux(id)
    num_fill, filters, filters_info, filters_names  = filt_f()
    
    # Take for response function only those filters which have flux in data
    num_fill = num_fill[filt]
    
    z_list = np.arange(0, 4, 0.5)
    L = np.zeros(len(z_list))
    templates_n = np.zeros(len(z_list))
    k = 0
    
    for i in range(len(z_list)):
       
        
        # Template wavelengths and fluxes
        x = np.genfromtxt(list[k])[:, 0]
        y = np.genfromtxt(list[k])[:, 1]

        fitz, mean_lambda = chi2(z_list[i], lci, x, y, num_fill, filters, filters_info, filters_names, flux_c)
        fitz = np.array(fitz)


        a = np.sum(fitz**2 / erflu_c**2)
        b = -2*np.sum(flux_c*fitz/ erflu_c**2)    
        n = -b/(2*a)
        L[i] = np.sum((flux_c - n*fitz)** 2 / (np.array(erflu_c) ** 2) )
        
        
 
        fig = plt.figure(i + 999)
        ax2 = fig.add_subplot(1,1,1)
        ax2.plot(lci, fitz*n, "s", color = 'yellow')
        #ax2.set_xlabel("z_my", fontsize=17)
        #ax2.set_ylabel("z_peak", fontsize=17)
        
        #ax2.set_xlim(0, 10)
        #ax2.set_ylim(0, 10)
        plt.plot(lci, flux_c, "o", color = "blue")
        #plt.legend(loc='lower right')
        plt.title("z = " + str(z_list[i]) + "   " + "z_spec = " + str(np.round(z_spec[8],1)))
        plt.savefig(str(id)+"-"+ str(z_list[i])+".png")
        plt.close()
        
        redsh = z_list[np.argmin(L)]
    
    return redsh

# %%
z = get_z(28864)
print(z)
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# 0.5

# %%
a
